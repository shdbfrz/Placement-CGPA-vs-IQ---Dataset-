# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %% [markdown]
# # New Section

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
df.sample(10)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 17          17   3.3  183.0          0
# 42          42   7.6   89.0          1
# 97          97   6.7  182.0          1
# 39          39   4.6  146.0          0
# 2            2   5.3  121.0          0
# 67          67   5.0  118.0          0
# 91          91   7.5  158.0          1
# 76          76   4.9  155.0          0
# 77          77   7.3   50.0          1
# 16          16   5.2  224.0          0

# %%
df.iq
# Out:
# 0     123.0
# 1     106.0
# 2     121.0
# 3     132.0
# 4     142.0
#       ...
# 95    200.0
# 96     42.0
# 97    182.0
# 98    103.0
# 99    113.0
# Name: iq, Length: 100, dtype: float64

# %%
df.size
# Out:
# 400

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %%
plt.scatter(df['placement'],df['iq'])

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     Unnamed: 0  cgpa
# 19          19   5.2
# 83          83   7.5
# 1            1   5.9
# 98          98   6.3
# 10          10   6.0
# ..         ...   ...
# 35          35   6.8
# 90          90   7.3
# 38          38   6.5
# 49          49   5.4
# 30          30   7.6
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     Unnamed: 0  cgpa
# 32          32   7.0
# 93          93   6.8
# 75          75   4.8
# 82          82   6.5
# 40          40   4.9
# 39          39   4.6
# 76          76   4.9
# 53          53   8.3
# 43          43   6.8
# 71          71   6.1

# %%
x_test.shape
# Out:
# (10, 2)

# %%
x_train.shape
# Out:
# (90, 2)

# %%
y_train
# Out:
# 19    0
# 83    1
# 1     0
# 98    1
# 10    1
#      ..
# 35    1
# 90    1
# 38    1
# 49    0
# 30    1
# Name: placement, Length: 90, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
y_test
# Out:
# 32    1
# 93    1
# 75    0
# 82    1
# 40    0
# 39    0
# 76    0
# 53    1
# 43    1
# 71    1
# Name: placement, dtype: int64

# %%
y_train.shape
# Out:
# (90,)

# %%
y_test.shape
# Out:
# (10,)

# %%
from sklearn.preprocessing import StandardScaler
Scalar=StandardScaler()
x_train=Scalar.fit_transform(x_train)
x_train
# Out:
# array([[-0.99573386, -0.68956539],
#        [ 1.18007306,  1.33799194],
#        [-1.60767956, -0.07248273],
#        [ 1.69002781,  0.28013594],
#        [-1.30170671,  0.01567194],
#        [-1.64167655,  0.72090927],
#        [ 0.12616658,  0.89721861],
#        [-0.24780023, -0.51325606],
#        [ 0.67011831, -1.74742139],
#        [ 0.60212435,  0.80906394],
#        [ 0.05817262, -2.18819472],
#        [-1.43769465, -0.24879206],
#        [-0.07781532, -0.60141073],
#        [-0.00982135,  0.54459994],
#        [-0.85974593, -1.13033872],
#        [-0.21380325,  1.42614661],
#        [-1.02973085, -1.74742139],
#        [ 0.73811228,  0.28013594],
#        [ 1.58803686, -1.48295739],
#        [-1.47169163,  0.98537327],
#        [ 1.65603083,  0.63275461],
#        [-0.82574895, -1.13033872],
#        [ 1.316061  , -0.24879206],
#        [ 0.87410021,  0.63275461],
#        [-1.23371275, -0.51325606],
#        [ 1.07808211, -0.95402939],
#        [ 0.36414547, -1.04218406],
#        [-1.1317218 , -0.77772006],
#        [ 1.7240248 ,  0.19198127],
#        [-0.48577912, -1.04218406],
#        [ 0.7041153 ,  2.21953861],
#        [ 0.19416055,  0.36829061],
#        [-1.57368258, -0.60141073],
#        [-0.89374292, -0.95402939],
#        [-0.65576403,  0.89721861],
#        [ 0.56812736,  1.86691994],
#        [ 0.97609116,  1.16168261],
#        [ 0.80610625,  1.16168261],
#        [ 1.01008815,  0.10382661],
#        [-0.38378817,  1.86691994],
#        [ 0.0921696 , -1.04218406],
#        [ 1.1120791 , -0.51325606],
#        [-0.9277399 ,  0.98537327],
#        [ 0.46613641,  0.01567194],
#        [-0.1118123 ,  0.01567194],
#        [ 0.53413038,  0.89721861],
#        [ 1.55403988, -1.13033872],
#        [-1.09772481, -0.68956539],
#        [ 1.38405496, -0.95402939],
#        [ 1.21407005, -0.24879206],
#        [-0.68976102, -0.68956539],
#        [-1.40369766, -0.86587473],
#        [ 1.24806703, -0.16063739],
#        [ 1.04408513,  0.45644527],
#        [-1.3357037 , -0.77772006],
#        [-1.5396856 ,  1.24983727],
#        [ 0.2961515 ,  0.45644527],
#        [-0.58777007, -1.83557606],
#        [-0.04381833, -0.68956539],
#        [-0.79175197, -0.86587473],
#        [ 1.28206401, -0.77772006],
#        [-1.36970068,  0.10382661],
#        [-0.14580928,  1.33799194],
#        [-0.41778515, -0.24879206],
#        [ 1.62203385, -1.39480272],
#        [-1.16571878,  0.10382661],
#        [ 0.22815753,  1.60245594],
#        [-0.5197761 ,  0.01567194],
#        [-1.19971576,  0.36829061],
#        [ 0.84010323, -0.95402939],
#        [-1.26770973,  0.80906394],
#        [-1.50568861, -0.16063739],
#        [-0.96173688,  0.54459994],
#        [ 1.48604591, -0.68956539],
#        [-0.723758  ,  0.01567194],
#        [ 0.33014848,  1.77876527],
#        [ 0.43213943,  1.16168261],
#        [ 0.39814245,  0.80906394],
#        [ 0.26215452,  0.10382661],
#        [ 1.45204893,  1.33799194],
#        [-0.75775498,  0.89721861],
#        [ 0.5001334 ,  0.28013594],
#        [ 0.63612133, -0.86587473],
#        [-1.06372783, -2.36450406],
#        [ 1.35005798, -1.39480272],
#        [-0.45178213,  0.72090927],
#        [ 1.41805195,  1.16168261],
#        [-0.34979118,  0.45644527],
#        [ 0.02417563, -0.51325606],
#        [-0.62176705,  1.42614661]])

# %%
x_test=Scalar.transform(x_test)
x_test
# Out:
# array([[-0.55377308,  0.89721861],
#        [ 1.5200429 ,  0.72090927],
#        [ 0.9080972 , -1.04218406],
#        [ 1.14607608,  0.45644527],
#        [-0.28179722, -0.95402939],
#        [-0.3157942 , -1.21849339],
#        [ 0.94209418, -0.95402939],
#        [ 0.16016357,  2.04322927],
#        [-0.17980627,  0.72090927],
#        [ 0.77210926,  0.10382661]])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 32    1
# 93    1
# 75    0
# 82    1
# 40    0
# 39    0
# 76    0
# 53    1
# 43    1
# 71    1
# Name: placement, dtype: int64

# %%
y_train
# Out:
# 19    0
# 83    1
# 1     0
# 98    1
# 10    1
#      ..
# 35    1
# 90    1
# 38    1
# 49    0
# 30    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# Convert DataFrame to NumPy arrays
X = x_train.values
y = y_train.values

plot_decision_regions(X=X, y=y, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('Decision Boundary')
plt.show()

# %%
plot_decision_regions(X=X, y=y, clf=clf, legend=2)
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('Decision Boundary')
plt.show()

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
